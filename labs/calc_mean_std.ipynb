# %%
from pathlib import Path

# %%
import cv2
import numpy as np
from tqdm import tqdm

# %%
images = sorted(Path('/home/jiun/datasets/amano/200203/train/images').glob('*.jpg'))

# %%
statics = []
for img in tqdm(map(cv2.imread, map(str, images)), total=len(images)):
    statics.append((img.mean((0, 1)), img.std((0, 1))))
# Out:
# 100%|██████████| 2139/2139 [13:35<00:00,  2.62it/s]

# %%
statics = np.array(statics)

# %%
mean, std = statics.mean(0)

# %%
mean, std
# Out:
# (array([135.20700061, 141.80240405, 136.55270982]),
#  array([43.54524555, 42.90410202, 43.92268492]))

# %%
print('done')
# Out:
# done

# %%
from PIL import Image
from IPython.display import display

def show(ary):
    display(Image.fromarray(ary))

# %%
image = next(Path('/home/jiun/datasets/amano/200203-up-down/train/images').glob('*.jpg'))
image = cv2.imread(str(image))

# %%
show(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x216 at 0x7F631C3A4450>

# %%
show(cv2.resize(image, ((1600, 300))))
# Out:
# <PIL.Image.Image image mode=RGB size=1600x300 at 0x7F631C0A86D0>
